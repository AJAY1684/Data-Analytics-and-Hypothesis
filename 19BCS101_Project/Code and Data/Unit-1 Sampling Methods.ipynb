# %% [markdown]
# # Marketing Anlysis

# %%
import pandas as pd
import numpy as np
from datetime import date
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("Company_Data.csv",index_col=0)
data
# Out:
#       Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# S.No
# 0           1970  Graduation         Single  84835.0        0         0
# 1           1961  Graduation         Single  57091.0        0         0
# 2           1958  Graduation        Married  67267.0        0         1
# 3           1967  Graduation        Married  32474.0        1         1
# 4           1989  Graduation         Single  21474.0        1         0
# ...          ...         ...            ...      ...      ...       ...
# 2232        1976         PhD         Single  66476.0        0         1
# 2233        1977      Master        Married  31056.0        1         0
# 2234        1976  Graduation         Single  46310.0        1         0
# 2235        1978  Graduation        Married  65819.0        0         0
# 2236        1969         PhD        Married  94871.0        0         2
#
#      Dt_Customer  Recency  MntWines  MntFruits  ...  AcceptedCmp4  \
# ...

# %% [markdown]
# # Simple Random Sampling

# %%
Sample = data.sample(n=30,replace=False) 
Sample
# Out:
#       Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# S.No
# 488         1954  Graduation         Single  50002.0        0         1
# 1772        1982      Master        Married  66664.0        0         0
# 934         1976      Master         Single  75012.0        0         0
# 987         1951      Master        Married  78497.0        0         0
# 121         1962  Graduation        Married  71434.0        0         1
# 1337        1993  Graduation         Single  79244.0        0         0
# 1432        1992       Basic         Single   7500.0        1         0
# 1033        1975      Master        Married  37284.0        1         1
# 732         1955      Master         Single  41769.0        0         1
# 1211        1978      Master        Married  51381.5        0         0
# 2120        1961      Master        Married  61923.0        0         2
# 262         1983  Graduation        Married  51381.5        1         0
# ...

# %% [markdown]
# # Systematic Random Sampling

# %%
# Ordering data by "Year_Birth"
df = data.sort_values(by=["Year_Birth"],ascending=False)    
n = len(df)

# %%
print("Select value from 0 to 9 : ")
x = int(input()) 
lst = []
i=x
while i<n:
    lst.append(i)
    i = i+x   
df.iloc[lst]
# Out:
# Select value from 0 to 9 :
# 4
#       Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# S.No
# 1466        1995  Graduation         Single  34824.0        0         0
# 686         1994  Graduation         Single  95529.0        0         0
# 1493        1993  Graduation         Single  74293.0        0         0
# 1542        1992  Graduation        Married  63207.0        0         0
# 930         1992       Basic         Single  18746.0        1         0
# ...          ...         ...            ...      ...      ...       ...
# 472         1945         PhD        Married  70356.0        0         0
# 1922        1944         PhD         Single  55614.0        0         0
# 1207        1943         PhD         Single  48948.0        0         0
# 1348        1943         PhD         Single  57513.0        0         0
# 2169        1940         PhD         Single  51141.0        0         0
#
# ...

# %% [markdown]
# # Cluster Sampling

# %%
import random
n = pd.unique(df['Country'])
n =n.tolist()
print("Countries are : ",n)
x = random.sample(n,1)
print("Randomly selected Country :" , x[0])
df2 =df.loc[data["Country"]==x[0]] 
df2
# Out:
# Countries are :  ['SP', 'CA', 'US', 'AUS', 'GER', 'IND', 'SA', 'ME']
# Randomly selected Country : US
#       Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# S.No
# 2           1958  Graduation        Married  67267.0        0         1
# 8           1954         PhD        Married  65324.0        0         1
# 10          1947      Master        Married  81044.0        0         0
# 49          1960  Graduation         Single  48904.0        0         1
# 93          1969         PhD        Married  69476.0        0         0
# ...          ...         ...            ...      ...      ...       ...
# 2214        1960         PhD         Single  50611.0        0         1
# 2215        1960         PhD         Single  50611.0        0         1
# 2216        1970  Graduation         Single  83273.0        1         2
# 2231        1973  Graduation         Single  78901.0        0         1
# ...

# %% [markdown]
# # Stratified Random Sampling

# %% [markdown]
# A sample of 100 is collected

# %%
strata1 = df.loc[ (df["Marital_Status"] == "Married") ]
strata2 = df.loc[ (df["Marital_Status"] == "Single") ]
Sample1 = strata1.sample(n=50,replace=False)
Sample2 = strata2.sample(n=50,replace=False) 
frames = [Sample1, Sample2]
  
result = pd.concat(frames)
display(result)
# Out:
#       Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# S.No
# 1528        1953  Graduation        Married  34587.0        1         1
# 621         1964  Graduation        Married  75236.0        0         1
# 2039        1978         PhD        Married  27683.0        1         0
# 746         1951         PhD        Married  53312.0        0         0
# 1117        1957         PhD        Married  37633.0        1         1
# ...          ...         ...            ...      ...      ...       ...
# 1807        1947         PhD         Single  68117.0        0         1
# 300         1982      Master         Single  75777.0        0         0
# 2216        1970  Graduation         Single  83273.0        1         2
# 1181        1970      Master         Single  29548.0        1         0
# 1644        1971         PhD         Single  60504.0        0         1
#
#      Dt_Customer  Recency  MntWines  MntFruits  ...  AcceptedCmp4  \
# ...

# %% [markdown]
# # MULTI STAGE SAMPLING

# %% [markdown]
# A sample of 40 need to be collected

# %%
import random
df = data
strata1 = df.loc[ (df["Marital_Status"] == "Married") ]
strata2 = df.loc[ (df["Marital_Status"] == "Single") ]
lst = ["s1","s2"]
n = random.sample(lst, 1)
print(n)
if n[0]=="s1":
    cluster1 = strata1.loc[ (df["Education"] == "Graduation") ]
    cluster2 = strata1.loc[ (df["Education"] == "PhD") ]
    cluster3 = strata1.loc[ (df["Education"] == "Master") ]
    cluster4 = strata1.loc[ (df["Education"] == "Basic") ]
    S1 = cluster1.sample(n=10,replace=False)
    S2 = cluster2.sample(n=10,replace=False)
    S3 = cluster3.sample(n=10,replace=False)
    S4 = cluster4.sample(n=10,replace=False)
    frames = [S1, S2, S3,S4]
    
    
elif n[0]=="s2":
    cluster1 = strata2.loc[ (df["Education"] == "Graduation") ]
    cluster2 = strata2.loc[ (df["Education"] == "PhD") ]
    cluster3 = strata2.loc[ (df["Education"] == "Master") ]
    cluster4 = strata2.loc[ (df["Education"] == "Basic") ]
    S1 = cluster1.sample(n=10,replace=False)
    S2 = cluster2.sample(n=10,replace=False)
    S3 = cluster3.sample(n=10,replace=False)
    S4 = cluster4.sample(n=10,replace=False)
    frames = [S1, S2, S3,S4]
    
result = pd.concat(frames)
result
# Out:
# ['s2']
#       Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# S.No
# 2066        1975  Graduation         Single  33955.0        1         0
# 280         1975  Graduation         Single  33249.0        1         0
# 456         1965  Graduation         Single   4861.0        0         0
# 1786        1954  Graduation         Single  76773.0        0         0
# 1604        1955  Graduation         Single  57959.0        0         1
# 854         1972  Graduation         Single  51813.0        1         1
# 1325        1988  Graduation         Single  20518.0        1         0
# 130         1954  Graduation         Single  72071.0        0         1
# 1758        1975  Graduation         Single  83829.0        0         0
# 1120        1952  Graduation         Single  69142.0        0         1
# 1753        1973         PhD         Single  54466.0        1         1
# 1103        1985         PhD         Single  37929.0        0         0
# ...
